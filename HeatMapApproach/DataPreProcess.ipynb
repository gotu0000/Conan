# %%
import sys
sys.path.insert(0, '../Common/')

import pandas as pd
import numpy as np 
from AISDataManager import AISDataManager
#config parser
import configparser
import Constants as c

#MyConfig.INI stores all the run time constants
config = configparser.ConfigParser()
config.read('../MyConfig.INI')

#make object of AIS data manager
aISDM = AISDataManager()

#this is the regeion of interest
lonMin = (float)(config['REGEION']['LON_MIN'])
lonMax = (float)(config['REGEION']['LON_MAX'])

latMin = (float)(config['REGEION']['LAT_MIN'])
latMax = (float)(config['REGEION']['LAT_MAX'])

print(lonMin,",",latMin)
print(lonMax,",",latMax)
# Out:
# -120.0 , 31.0
# -117.0 , 34.5

# %%
fileNameList = [("../Data/RawData/AIS_2015_Zone_11/AIS_2015_01_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_02_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_03_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_04_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_05_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_06_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_07_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_08_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_09_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_09_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_10_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_10_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_11_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_11_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_12_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_12_LAP.csv")\
                
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_01_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_01_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_02_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_02_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_03_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_03_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_04_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_04_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_05_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_05_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_06_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_06_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_07_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_07_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_08_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_08_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_09_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_09_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_10_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_10_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_11_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_11_LAP.csv")\
                ,("../Data/RawData/AIS_2016_Zone_11/AIS_2016_12_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_12_LAP.csv")\
                
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_01_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_01_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_02_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_02_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_03_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_03_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_04_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_04_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_05_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_05_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_06_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_06_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_07_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_07_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_08_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_08_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_09_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_09_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_10_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_10_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_11_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_11_LAP.csv")\
                ,("../Data/RawData/AIS_2017_Zone_11/AIS_2017_12_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2017_12_LAP.csv")\
               ]

# %% [markdown]
# #Below cell converts the data limited to LA Port

# %%
#iterate through files list
#cropp the data for the desired regeion
for i in fileNameList:
    print(i)
    aISDM.save_data_for_targeted_area(i[0],lonMin,lonMax,latMin,latMax,i[1])
# Out:
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_01_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_02_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_03_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_04_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_05_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_06_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_07_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP.csv')
# ('../Data/RawData/AIS_2015_Zone_11/AIS_2015_08_Zone11.csv', '../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP.csv')
# ...

# %% [markdown]
# #Below cell converts the limited LA Port data to Sorted data i.e increasing order of time

# %%
for i in fileNameList:
    lAPData,retVal = aISDM.load_data_from_csv(i[1])
    if(retVal == c.errNO['SUCCESS']):
        tempDF = aISDM.formate_time(lAPData,'DateTime')
        tempDF = tempDF.sort_values(by='DateTime')
        fileName = i[1].replace('.csv','_Sorted.csv')
        print(fileName)
        aISDM.save_data_to_csv(tempDF,fileName)
# Out:
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_09_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_10_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_11_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_12_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_01_LAP_Sorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_02_LAP_Sorted.csv
# ...

# %% [markdown]
# #below cell drops certain columns which are not needed for heat map

# %%
for i in fileNameList:
    lAPData,retVal = aISDM.load_data_from_csv(i[1])
    if(retVal == c.errNO['SUCCESS']):
        tempDF = aISDM.drop_columns(lAPData)
        fileName = i[1].replace('.csv','_Dropped.csv')
        print(fileName)
        aISDM.save_data_to_csv(tempDF,fileName)
# Out:
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_09_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_10_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_11_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_12_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_01_LAP_Dropped.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_02_LAP_Dropped.csv
# ...

# %%
for i in fileNameList:
    fileNameToRead = i[1].replace('.csv','_Dropped.csv')
    lAPData,retVal = aISDM.load_data_from_csv(fileNameToRead)
    if(retVal == c.errNO['SUCCESS']):
        tempDF = aISDM.formate_time(lAPData,'DateTime')
        tempDF = tempDF.sort_values(by='DateTime')
        fileName = i[1].replace('.csv','_DrSorted.csv')
        print(fileName)
        aISDM.save_data_to_csv(tempDF,fileName)
# Out:
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_09_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_10_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_11_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_12_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_01_LAP_DrSorted.csv
# ../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_02_LAP_DrSorted.csv
# ...

# %%
#generate list of unique entries for entire regeion
vesselListSets = []
for i in fileNameList:
    lAPData,retVal = aISDM.load_data_from_csv(i[1])
    if(retVal == c.errNO['SUCCESS']):
        vesselListSets.append(aISDM.get_list_of_unique_mmsi(lAPData))
    else:
        print("Unable to load")
        break;

#make empty set
unionOfVesselList = set()
#get unioun of all the sets
for i in vesselListSets:
    unionOfVesselList = unionOfVesselList.union(set(i))

#convert set to list
unionOfVesselList = list(unionOfVesselList)

#sort them
sortedMMSI = unionOfVesselList.copy()
sortedMMSI.sort()

#save to file 
with open('../Data/AIS_0115_1217_31_M120_345_M117/Output/MMSIList.txt', 'w') as f:
    for item in sortedMMSI:
        f.write("%s\n" % item)

# %%
#generate list of unique entries for entire regeion
vesselListSets = []
fileNameList15 = [("../Data/RawData/AIS_2015_Zone_11/AIS_2015_01_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_01_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_02_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_02_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_03_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_03_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_04_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_04_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_05_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_05_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_06_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_06_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_07_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_07_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_08_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_08_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_09_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_09_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_10_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_10_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_11_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_11_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2015_12_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2015_12_LAP.csv")\
                 ]
for i in fileNameList:
    lAPData,retVal = aISDM.load_data_from_csv(i[1])
    if(retVal == c.errNO['SUCCESS']):
        vesselListSets.append(aISDM.get_list_of_unique_mmsi(lAPData))
    else:
        print("Unable to load")
        break;

#make empty set
unionOfVesselList = set()
#get unioun of all the sets
for i in vesselListSets:
    unionOfVesselList = unionOfVesselList.union(set(i))

#convert set to list
unionOfVesselList = list(unionOfVesselList)

#sort them
sortedMMSI = unionOfVesselList.copy()
sortedMMSI.sort()

#save to file 
with open('../Data/AIS_0115_1217_31_M120_345_M117/Output/MMSIList15.txt', 'w') as f:
    for item in sortedMMSI:
        f.write("%s\n" % item)

# %%
#generate list of unique entries for entire regeion
vesselListSets = []
fileNameList15 = [("../Data/RawData/AIS_2015_Zone_11/AIS_2016_01_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_01_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_02_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_02_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_03_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_03_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_04_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_04_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_05_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_05_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_06_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_06_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_07_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_07_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_08_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_08_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_09_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_09_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_10_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_10_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_11_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_11_LAP.csv")\
                ,("../Data/RawData/AIS_2015_Zone_11/AIS_2016_12_Zone11.csv",\
                "../Data/AIS_0115_1217_31_M120_345_M117/AIS_2016_12_LAP.csv")\
                 ]
for i in fileNameList:
    lAPData,retVal = aISDM.load_data_from_csv(i[1])
    if(retVal == c.errNO['SUCCESS']):
        vesselListSets.append(aISDM.get_list_of_unique_mmsi(lAPData))
    else:
        print("Unable to load")
        break;

#make empty set
unionOfVesselList = set()
#get unioun of all the sets
for i in vesselListSets:
    unionOfVesselList = unionOfVesselList.union(set(i))

#convert set to list
unionOfVesselList = list(unionOfVesselList)

#sort them
sortedMMSI = unionOfVesselList.copy()
sortedMMSI.sort()

#save to file 
with open('../Data/AIS_0115_1217_31_M120_345_M117/Output/MMSIList16.txt', 'w') as f:
    for item in sortedMMSI:
        f.write("%s\n" % item)
